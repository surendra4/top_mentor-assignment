# %%
#pandas 
import pandas as pd
data = pd.read_csv('C:/Users/Surendra/Desktop/data science/TOP MENTOR/mysql/Top_mentor_projects_Datasets-main/Top_mentor_projects_Datasets-main./car_sales.csv')
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data.head(5)
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
data.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
data1 = data.copy()
data1
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data1.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales_in_thousands     float64
# __year_resale_value    float64
# Vehicle_type            object
# Price_in_thousands     float64
# Engine_size            float64
# Horsepower             float64
# Wheelbase              float64
# Width                  float64
# Length                 float64
# Curb_weight            float64
# Fuel_capacity          float64
# Fuel_efficiency        float64
# Latest_Launch           object
# Power_perf_factor      float64
# dtype: object

# %%
type(data1)
# Out:
# pandas.core.frame.DataFrame

# %%
data1.mean()
# Out:
# Sales_in_thousands      52.998076
# __year_resale_value     18.072975
# Price_in_thousands      27.390755
# Engine_size              3.060897
# Horsepower             185.948718
# Wheelbase              107.487179
# Width                   71.150000
# Length                 187.343590
# Curb_weight              3.378026
# Fuel_capacity           17.951923
# Fuel_efficiency         23.844156
# Power_perf_factor       77.043591
# dtype: float64

# %%
type(data1), data1.dtypes
# Out:
# (pandas.core.frame.DataFrame,
#  Manufacturer            object
#  Model                   object
#  Sales_in_thousands     float64
#  __year_resale_value    float64
#  Vehicle_type            object
#  Price_in_thousands     float64
#  Engine_size            float64
#  Horsepower             float64
#  Wheelbase              float64
#  Width                  float64
#  Length                 float64
#  Curb_weight            float64
#  Fuel_capacity          float64
#  Fuel_efficiency        float64
#  Latest_Launch           object
#  Power_perf_factor      float64
#  dtype: object)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %%
data1['Engine_size']
# Out:
# 0      1.8
# 1      3.2
# 2      3.2
# 3      3.5
# 4      1.8
#       ...
# 152    1.9
# 153    2.4
# 154    2.4
# 155    2.3
# 156    2.9
# Name: Engine_size, Length: 157, dtype: float64

# %%
A1 = data1[['Latest_Launch','Fuel_capacity','Latest_Launch']].head(10)
A1
# Out:
#   Latest_Launch  Fuel_capacity Latest_Launch
# 0    02-02-2012           13.2    02-02-2012
# 1    06-03-2011           17.2    06-03-2011
# 2    01-04-2012           17.2    01-04-2012
# 3    03-10-2011           18.0    03-10-2011
# 4    10-08-2011           16.4    10-08-2011
# 5    08-09-2011           18.5    08-09-2011
# 6     2/27/2012           23.7     2/27/2012
# 7     6/28/2011           16.6     6/28/2011
# 8     1/29/2012           16.6     1/29/2012
# 9    04-04-2011           18.5    04-04-2011

# %%
A1.shape
# Out:
# (10, 3)

# %%
s = [10,12,14,15,16,18,19,11,22,11]
A1['rank']= s
A1
# Out:
#   Latest_Launch  Fuel_capacity Latest_Launch  rank
# 0    02-02-2012           13.2    02-02-2012    10
# 1    06-03-2011           17.2    06-03-2011    12
# 2    01-04-2012           17.2    01-04-2012    14
# 3    03-10-2011           18.0    03-10-2011    15
# 4    10-08-2011           16.4    10-08-2011    16
# 5    08-09-2011           18.5    08-09-2011    18
# 6     2/27/2012           23.7     2/27/2012    19
# 7     6/28/2011           16.6     6/28/2011    11
# 8     1/29/2012           16.6     1/29/2012    22
# 9    04-04-2011           18.5    04-04-2011    11

# %%
mpg = pd.Series([35,54,2,5,55,76])
A1['mpg'] = mpg
A1
# Out:
#   Latest_Launch  Fuel_capacity Latest_Launch   mpg
# 0    02-02-2012           13.2    02-02-2012  35.0
# 1    06-03-2011           17.2    06-03-2011  54.0
# 2    01-04-2012           17.2    01-04-2012   2.0
# 3    03-10-2011           18.0    03-10-2011   5.0
# 4    10-08-2011           16.4    10-08-2011  55.0
# 5    08-09-2011           18.5    08-09-2011  76.0
# 6     2/27/2012           23.7     2/27/2012   NaN
# 7     6/28/2011           16.6     6/28/2011   NaN
# 8     1/29/2012           16.6     1/29/2012   NaN
# 9    04-04-2011           18.5    04-04-2011   NaN

# %%
data1.sample(frac=.05)    #suffle 5-% of data in datafrome
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 140       Toyota          Tacoma              84.087                9.575
# 150   Volkswagen          Beetle              49.463                  NaN
# 105       Nissan      Pathfinder              42.574               17.810
# 48          Ford         Contour              35.068                8.835
# 85    Mitsubishi   Montero Sport              39.348               13.880
# 92    Mercedes-B         C-Class              18.392               26.050
# 16      Cadillac        Eldorado               6.536               25.725
# 126      Porsche  Carrera Cabrio               1.866               67.550
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 140          Car              11.528          2.4       142.0      103.3
# 150    Passenger              15.900          2.0       115.0       98.9
# 105          Car              29.299          3.3       170.0      106.3
# ...

# %%
data1.isna().sum()#.sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
data1 = data1.sample(frac =1)
data1
# Out:
#     Manufacturer          Model  Sales_in_thousands  __year_resale_value  \
# 139       Toyota         Celica              33.269               15.445
# 151        Volvo            S40              16.957                  NaN
# 30      Chrysler       Concorde              31.148               13.725
# 88       Mercury          Sable              67.956               11.030
# 66        Jaguar         S-Type              15.467                  NaN
# ..           ...            ...                 ...                  ...
# 28      Chrysler  Sebring Coupe               7.854               12.360
# 147   Volkswagen         Passat              51.102               16.725
# 156        Volvo            S80              18.969                  NaN
# 148   Volkswagen         Cabrio               9.569               16.575
# 97    Mercedes-B         SLK230               1.526                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
data1.reset_index()   #to get the indext value in order
# Out:
#      index Manufacturer          Model  Sales_in_thousands  \
# 0      139       Toyota         Celica              33.269
# 1      151        Volvo            S40              16.957
# 2       30     Chrysler       Concorde              31.148
# 3       88      Mercury          Sable              67.956
# 4       66       Jaguar         S-Type              15.467
# ..     ...          ...            ...                 ...
# 152     28     Chrysler  Sebring Coupe               7.854
# 153    147   Volkswagen         Passat              51.102
# 154    156        Volvo            S80              18.969
# 155    148   Volkswagen         Cabrio               9.569
# 156     97   Mercedes-B         SLK230               1.526
#
#      __year_resale_value Vehicle_type  Price_in_thousands  Engine_size  \
# 0                 15.445    Passenger              16.875          1.8
# 1                    NaN    Passenger              23.400          1.9
# ...

# %%
data1 = data1.reset_index(drop =True) # to reset the index value in data1

# %%
data1
# Out:
#     Manufacturer          Model  Sales_in_thousands  __year_resale_value  \
# 0         Toyota         Celica              33.269               15.445
# 1          Volvo            S40              16.957                  NaN
# 2       Chrysler       Concorde              31.148               13.725
# 3        Mercury          Sable              67.956               11.030
# 4         Jaguar         S-Type              15.467                  NaN
# ..           ...            ...                 ...                  ...
# 152     Chrysler  Sebring Coupe               7.854               12.360
# 153   Volkswagen         Passat              51.102               16.725
# 154        Volvo            S80              18.969                  NaN
# 155   Volkswagen         Cabrio               9.569               16.575
# 156   Mercedes-B         SLK230               1.526                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
data1.fillna(0, inplace =True)   #will assing in orignal place any place they have
data1
# Out:
#     Manufacturer          Model  Sales_in_thousands  __year_resale_value  \
# 0         Toyota         Celica              33.269               15.445
# 1          Volvo            S40              16.957                0.000
# 2       Chrysler       Concorde              31.148               13.725
# 3        Mercury          Sable              67.956               11.030
# 4         Jaguar         S-Type              15.467                0.000
# ..           ...            ...                 ...                  ...
# 152     Chrysler  Sebring Coupe               7.854               12.360
# 153   Volkswagen         Passat              51.102               16.725
# 154        Volvo            S80              18.969                0.000
# 155   Volkswagen         Cabrio               9.569               16.575
# 156   Mercedes-B         SLK230               1.526                0.000
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
data1.loc[1]  #by locatin of value
# Out:
# Manufacturer               Volvo
# Model                        S40
# Sales_in_thousands        16.957
# __year_resale_value          0.0
# Vehicle_type           Passenger
# Price_in_thousands          23.4
# Engine_size                  1.9
# Horsepower                 160.0
# Wheelbase                  100.5
# Width                       67.6
# Length                     176.6
# Curb_weight                2.998
# Fuel_capacity               15.8
# Fuel_efficiency             25.0
# Latest_Launch          2/18/2011
# Power_perf_factor      66.113057
# Name: 1, dtype: object

# %%
data1.iloc[[0,1,3,6],[1,2,3]]  #by location of index value
# Out:
#     Model  Sales_in_thousands  __year_resale_value
# 0  Celica              33.269               15.445
# 1     S40              16.957                0.000
# 3   Sable              67.956               11.030
# 6  Catera              11.185               18.225

# %%
data.loc[::-1]
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 156        Volvo      S80              18.969                  NaN
# 155        Volvo      C70               3.493                  NaN
# 154        Volvo      V70              17.531                  NaN
# 153        Volvo      S70              15.245                  NaN
# 152        Volvo      V40               3.545                  NaN
# ..           ...      ...                 ...                  ...
# 4           Audi       A4              20.397               22.255
# 3          Acura       RL               8.588               29.725
# 2          Acura       CL              14.114               18.225
# 1          Acura       TL              39.384               19.875
# 0          Acura  Integra              16.919               16.360
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 156    Passenger               36.00          2.9       201.0      109.9
# ...

# %%
data1.style.highlight_min()
# Out:
# <style  type="text/css" >
# ...

# %%
d = data1.head(10)
d.style.bar()
# Out:
# <style  type="text/css" >
# #T_79128_row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 40.5%, transparent 40.5%);
#         }#T_79128_row0_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 25.5%, transparent 25.5%);
#         }#T_79128_row0_col5,#T_79128_row0_col6,#T_79128_row0_col7,#T_79128_row0_col10,#T_79128_row0_col11,#T_79128_row0_col12,#T_79128_row0_col15,#T_79128_row1_col3,#T_79128_row1_col9,#T_79128_row4_col3,#T_79128_row4_col13,#T_79128_row5_col2,#T_79128_row5_col8,#T_79128_row5_col13,#T_79128_row7_col3,#T_79128_row8_col3{
#             width:  10em;
#              height:  80%;
#         }#T_79128_row0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 44.7%, transparent 44.7%);
#         }#T_79128_row0_col9{
#             width:  10em;
# ...

# %%
d.style.hide_index()
# Out:
# <style  type="text/css" >
# ...
