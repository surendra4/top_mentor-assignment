# %%
# %matplotlib inline
import pandas as pd

# %%
cast = pd.read_csv('C:/Users/Surendra/Desktop/data science/TOP MENTOR/PYTHON/cast.csv')
cast.head(7)

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %%
cast.shape
# Out:
# (3611212, 6)

# %%
cast['title']
# Out:
# 0                            Closet Monster
# 1                           Suuri illusioni
# 2                       Battle of the Sexes
# 3                      Secret in Their Eyes
# 4                                Steve Jobs
#                          ...
# 3611207                             Foxtrot
# 3611208    Niceland (Population. 1.000.002)
# 3611209                           Skammdegi
# 3611210                        U.S.S.S.S...
# 3611211                   Bye Bye Blue Bird
# Name: title, Length: 3611212, dtype: object

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
d = cast.sort_values('year')
d
# Out:
#                          title  year               name     type  \
# 2514470             Miss Jerry  1894    Blanche Bayliss  actress
# 555929              Miss Jerry  1894     Chauncey Depew    actor
# 464860              Miss Jerry  1894  William Courtenay    actor
# 1718214  Soldiers of the Cross  1900          Reg Perry    actor
# 1718063  Soldiers of the Cross  1900        Orrie Perry    actor
# ...                        ...   ...                ...      ...
# 2756653  The Supreme Gentleman  2023  Erika Etzelmiller  actress
# 28489                Inside Me  2023     Antonio Alcala    actor
# 2800939            Gnome Alone  2023           Becky G.  actress
# 3592140            Fetish Trap  2023     Karen Yamileth  actress
# 1697058              Inside Me  2023       Natalee Paul    actor
#
#                                                  character   n
# 2514470               Miss Geraldine Holbrook (Miss Jerry) NaN
# ...

# %%
d[0:2]
# Out:
#               title  year             name     type  \
# 2514470  Miss Jerry  1894  Blanche Bayliss  actress
# 555929   Miss Jerry  1894   Chauncey Depew    actor
#
#                                                  character   n
# 2514470               Miss Geraldine Holbrook (Miss Jerry) NaN
# 555929   Himself - the Director of the New York Central... NaN

# %% [markdown]
# ### How many movies have the title "Hamlet"?

# %%
cast[cast['title']== 'Hamlet']
# Out:
#           title  year              name     type              character     n
# 1615     Hamlet  1996        Riz Abbasi    actor  Attendant to Claudius   1.0
# 7438     Hamlet  1921  Fritz Achterberg    actor            Fortinbras,   9.0
# 11242    Hamlet  2009      Hayden Adams    actor                Laertes   7.0
# 11243    Hamlet  2009      Hayden Adams    actor                 Player   7.0
# 13907    Hamlet  1913       Eric Adeney    actor               Reynaldo  14.0
# ...         ...   ...               ...      ...                    ...   ...
# 3505738  Hamlet  1969    Jennifer Tudor  actress             Court lady  23.0
# 3528322  Hamlet  2000      Diane Venora  actress               Gertrude   3.0
# 3557773  Hamlet  1996     Perdita Weeks  actress          Second Player  44.0
# 3562331  Hamlet  2015   Katie (II) West  actress                Ophelia   7.0
# 3578802  Hamlet  1996      Kate Winslet  actress                Ophelia  46.0
#
# [313 rows x 6 columns]

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
cast[cast['title']==  "North by Northwest"]
# Out:
#                       title  year               name     type  \
# 12151    North by Northwest  1959      Stanley Adams    actor
# 27852    North by Northwest  1959         Andy Albin    actor
# 54093    North by Northwest  1959       Don Anderson    actor
# 54307    North by Northwest  1959    Ernest Anderson    actor
# 92195    North by Northwest  1959  Malcolm Atterbury    actor
# ...                     ...   ...                ...      ...
# 3361396  North by Northwest  1959    Eva Marie Saint  actress
# 3416124  North by Northwest  1959        Doris Singh  actress
# 3437248  North by Northwest  1959       Helen Spring  actress
# 3567500  North by Northwest  1959      Susan Whitney  actress
# 3578877  North by Northwest  1959     Paula Winslowe  actress
#
#                                  character    n
# 12151                   Lieutenant Harding  NaN
# 27852                               Farmer  NaN
# 54093                               Worker  NaN
# ...

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
l = cast[cast['title']==  "Hamlet"]
l
# Out:
#           title  year              name     type              character     n
# 1615     Hamlet  1996        Riz Abbasi    actor  Attendant to Claudius   1.0
# 7438     Hamlet  1921  Fritz Achterberg    actor            Fortinbras,   9.0
# 11242    Hamlet  2009      Hayden Adams    actor                Laertes   7.0
# 11243    Hamlet  2009      Hayden Adams    actor                 Player   7.0
# 13907    Hamlet  1913       Eric Adeney    actor               Reynaldo  14.0
# ...         ...   ...               ...      ...                    ...   ...
# 3505738  Hamlet  1969    Jennifer Tudor  actress             Court lady  23.0
# 3528322  Hamlet  2000      Diane Venora  actress               Gertrude   3.0
# 3557773  Hamlet  1996     Perdita Weeks  actress          Second Player  44.0
# 3562331  Hamlet  2015   Katie (II) West  actress                Ophelia   7.0
# 3578802  Hamlet  1996      Kate Winslet  actress                Ophelia  46.0
#
# [313 rows x 6 columns]

# %%
A = l.sort_values('year')
A[0:1]
# Out:
#           title  year               name   type character   n
# 1545289  Hamlet  1910  Jean Mounet-Sully  actor    Hamlet NaN

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
t= cast[cast['title']==  "Treasure Island"]
t.sort_values('year')
# Out:
#                    title  year                  name     type  \
# 830114   Treasure Island  1918        Charles Gorman    actor
# 840745   Treasure Island  1918             Joe Grant    actor
# 909157   Treasure Island  1918          Edwin Harley    actor
# 3298306  Treasure Island  1918      Violet Radcliffe  actress
# 1715014  Treasure Island  1918            Lloyd Perl    actor
# ...                  ...   ...                   ...      ...
# 2420089  Treasure Island  1999          Caveh Zahedi    actor
# 1637661  Treasure Island  1999         Nick Offerman    actor
# 1375015  Treasure Island  1999           J.P. Manoux    actor
# 1797264  Treasure Island  1999  Victor Raider-Wexler    actor
# 307749   Treasure Island  1999          Bob Byington    actor
#
#                        character     n
# 830114           Prologue Player   NaN
# 840745   Undetermined child role   NaN
# 909157           Prologue Player   NaN
# 3298306         Long John Silver   3.0
# ...

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
q = cast[cast['year'] == 1950]
q
# Out:
#                              title  year              name     type  \
# 266               Palletoori Pilla  1950    Subba Rao A.V.    actor
# 429                   Hallin Janne  1950    Kosti Aaltonen    actor
# 430                   Hallin Janne  1950    Kosti Aaltonen    actor
# 1481     Fortunes of Captain Blood  1950    Abdullah Abbas    actor
# 1497          The Baron of Arizona  1950    Abdullah Abbas    actor
# ...                            ...   ...               ...      ...
# 3610440           La vida en broma  1950     Dalia ??iguez  actress
# 3610445               Quinto patio  1950     Dalia ??iguez  actress
# 3610681    Harukanari haha no kuni  1950     Chiharu ?tomo  actress
# 3610827       Anderssonskans Kalle  1950  Ingrid ?stergren  actress
# 3611137         Akdeniz korsanlari  1950   Muazzez ?lkerer  actress
#
#                                  character    n
# 266                          Kampanna Dora  4.0
# 429                                  Rosvo  NaN
# ...

# %%
len(q)
# Out:
# 22006

# %% [markdown]
# ### How many movies were made in the year 1960?

# %%
p = cast[cast['year'] == 1960]
p
# Out:
#                               title  year                      name     type  \
# 68                     De zaak M.P.  1960             Frans 't Hoen    actor
# 115             Thunder in Carolina  1960  2nd Marine Division Band    actor
# 133                        Noi duri  1960              5 Asternovas    actor
# 265      Sri Venkateswara Mahatmyam  1960        Subba Rao A.V. Jr.    actor
# 268      Sri Venkateswara Mahatmyam  1960            Subba Rao A.V.    actor
# ...                             ...   ...                       ...      ...
# 3610216                     Domaren  1960         Inga-Lill ?hstr?m  actress
# 3610248    Alla vi barn i Bullerbyn  1960                Kim ?sberg  actress
# 3610684             Kawaita mizuumi  1960             Yachiyo ?tori  actress
# 3611050                    Omringet  1960             Kari ?ksnevad  actress
# 3611127                      Venner  1960              Bibba ?ygard  actress
#
# ...

# %%
len(p)
# Out:
# 18456

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
q = cast[(cast['year'] >=1950) & (cast['year']<=1959)]
q
# Out:
#                          title  year                  name     type  \
# 67             Fire Down Below  1957  'Stretch' Cox Troupe    actor
# 69          Dorp aan de rivier  1958         Frans 't Hoen    actor
# 111       Ci sposeremo a Capri  1956         Quartetto 2+2    actor
# 118             Die Todesarena  1953      Die 3 Motorellos    actor
# 266           Palletoori Pilla  1950        Subba Rao A.V.    actor
# ...                        ...   ...                   ...      ...
# 3611102       Styrmand Karlsen  1958            Clara ?st?  actress
# 3611103       Styrmand Karlsen  1958            Clara ?st?  actress
# 3611105  Tre piger fra Jylland  1957            Clara ?st?  actress
# 3611119                   Toya  1956            Aslaug ?ye  actress
# 3611137     Akdeniz korsanlari  1950       Muazzez ?lkerer  actress
#
#                  character     n
# 67          Limbo Dance by  20.0
# 69                Dirk Jan  15.0
# 111             Themselves  19.0
# ...

# %%
len(q)
# Out:
# 210986

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
b= cast[cast['title'] == 'Batman']
b
# Out:
#           title  year               name     type                   character  \
# 95672    Batman  1943       Frank Austin    actor                 Hotel Clerk
# 96186    Batman  1943     William Austin    actor           Alfred Pennyworth
# 114034   Batman  1989          Del Baker    actor                 Napier Hood
# 119476   Batman  1989    Michael Balfour    actor                   Scientist
# 149767   Batman  1989         David Baxt    actor            Dr. Thomas Wayne
# ...         ...   ...                ...      ...                         ...
# 2907449  Batman  1989        Sharon Holm  actress                  Mrs. Wayne
# 3253550  Batman  1943  Shirley Patterson  actress                  Linda Page
# 3343947  Batman  1989           Pam Rose  actress  Party Guest at Wayne Manor
# 3345872  Batman  1989          Liza Ross  actress                 Tourist Mom
# 3356826  Batman  1989        Rachel Ryan  actress                      Corpse
#
#             n
# 95672     NaN
# ...

# %%
len(b)
# Out:
# 120

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
i= cast[cast['title'] == 'Inception']
i
# Out:
#              title  year                  name     type  \
# 94333    Inception  2010  Michael (III) August    actor
# 143138   Inception  2010          Peter Basham    actor
# 176819   Inception  2010          Tom Berenger    actor
# 190249   Inception  2010              Ken Bhan    actor
# 250191   Inception  2010        Virgile Bramly    actor
# ...            ...   ...                   ...      ...
# 3238950  Inception  2010            Ellen Page  actress
# 3292669  Inception  2010        Nicole Pulliam  actress
# 3319073  Inception  2010    Lisa (II) Reynolds  actress
# 3325768  Inception  2010         Talulah Riley  actress
# 3560127  Inception  2010        Shannon Welles  actress
#
#                      character     n
# 94333            LAX Passenger   NaN
# 143138   Fischer's Jet Captain  44.0
# 176819                Browning   8.0
# 190249        Mombasan Gambler   NaN
# 250191          Bridge Sub Con  29.0
# ...                        ...   ...
# ...

# %%
k= i.name
len(k)
# Out:
# 77

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
l=cast[cast['title'] == 'Inception']

# %%
l['n'].isna().sum()
# Out:
# 26

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %%
l['n'].notna().sum()
# Out:
# 51

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
n = cast[cast['title'] == "North by Northwest" ]
n.sort_values('n')
n.dropna()
# Out:
#                       title  year                  name     type  \
# 198496   North by Northwest  1959          Edward Binns    actor
# 343701   North by Northwest  1959        Leo G. Carroll    actor
# 447893   North by Northwest  1959       Philip Coolidge    actor
# 642085   North by Northwest  1959     Robert Ellenstein    actor
# 840374   North by Northwest  1959            Cary Grant    actor
# 1229083  North by Northwest  1959         Martin Landau    actor
# 1334726  North by Northwest  1959             Ken Lynch    actor
# 1404704  North by Northwest  1959           James Mason    actor
# 1454363  North by Northwest  1959         Patrick McVey    actor
# 1634552  North by Northwest  1959           Philip Ober    actor
# 1746383  North by Northwest  1959          Edward Platt    actor
# 2212083  North by Northwest  1959          Les Tremayne    actor
# 2357939  North by Northwest  1959         Adam Williams    actor
# ...

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
s = cast[(cast['title'] ==  "Sleuth") & (cast['year'] == 1972)]
s.sort_values('n',ascending = True)
# Out:
#           title  year                name     type  \
# 1644328  Sleuth  1972    Laurence Olivier    actor
# 314691   Sleuth  1972       Michael Caine    actor
# 360365   Sleuth  1972      Alec Cawthorne    actor
# 1412647  Sleuth  1972  John (II) Matthews    actor
# 2619278  Sleuth  1972  Eve (III) Channing  actress
# 1396572  Sleuth  1972        Teddy Martin    actor
#
#                           character    n
# 1644328                 Andrew Wyke  1.0
# 314691                  Milo Tindle  2.0
# 360365            Inspector Doppler  3.0
# 1412647  Detective Sergeant Tarrant  4.0
# 2619278             Marguerite Wyke  5.0
# 1396572      Police Constable Higgs  6.0

# %% [markdown]
# ### Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
s = cast[(cast['title'] ==  "Sleuth") & (cast['year'] == 2007)]
s.sort_values('n',ascending = True)
# Out:
#           title  year                 name     type          character    n
# 314692   Sleuth  2007        Michael Caine    actor             Andrew  1.0
# 1246855  Sleuth  2007             Jude Law    actor               Milo  2.0
# 1741124  Sleuth  2007        Harold Pinter    actor        Man on T.V.  3.0
# 250297   Sleuth  2007      Kenneth Branagh    actor  Other Man on T.V.  NaN
# 360366   Sleuth  2007  Alec (II) Cawthorne    actor  Inspector Doppler  NaN
# 2619277  Sleuth  2007    Eve (II) Channing  actress    Marguerite Wyke  NaN
# 3223502  Sleuth  2007    Carmel O'Sullivan  actress             Maggie  NaN

# %%
h= len(s)
h
# Out:
# 7

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %%
s = cast[(cast['title'] ==  "Hamlet") & (cast['year'] == 1921)]
s
# Out:
#           title  year                    name     type         character    n
# 7438     Hamlet  1921        Fritz Achterberg    actor       Fortinbras,  9.0
# 442224   Hamlet  1921            Paul Conradi    actor      K?nig Hamlet  2.0
# 535307   Hamlet  1921        Anton De Verdier    actor           Laertes  7.0
# 1095274  Hamlet  1921         Hans Junkermann    actor          Polonius  6.0
# 2106367  Hamlet  1921            Heinz Stieda    actor           Horatio  5.0
# 2289163  Hamlet  1921  Eduard von Winterstein    actor          Claudius  4.0
# 2562876  Hamlet  1921         Mathilde Brandt  actress  K?nigin Gertrude  3.0
# 2935728  Hamlet  1921          Lilly Jacobson  actress           Ophelia  8.0
# 3209199  Hamlet  1921            Asta Nielsen  actress            Hamlet  1.0

# %%
k = cast[(cast['name']== 'the silent')]
k
len(k)
# Out:
# 0

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
s = cast[(cast['title'] ==  "Hamlet") & (cast['year'] == 1996) & (cast['name']== 'Kenneth Branagh')]
s
# Out:
#          title  year             name   type character    n
# 250281  Hamlet  1996  Kenneth Branagh  actor    Hamlet  5.0

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %%
s = cast[(cast['title'] ==  "Hamlet")]
q= s.character
d =[]
d= q.unique()
d
# Out:
# array(['Attendant to Claudius', 'Fortinbras,', 'Laertes', 'Player',
#        'Reynaldo', 'Fortinbras', 'Cornelius', 'Second Gravedigger',
#        'English Ambassador', 'Second Player', 'Marcellus', 'Rosencrantz',
#        'Horatio', 'Polonius - Lord Chamberlain', 'Polonius', 'Osric',
#        'Claudius', "Ghost of Hamlet's Father", 'Cadet in Play', 'Hamlet',
#        'Priest', 'Bit Part', 'Ghost ', ' Player King', 'Gravedigger',
#        'Laertes Mob', 'Player King', 'The Players', 'Butler', 'Francisco',
#        'K?nig Hamlet', 'Voltimand', 'First Gravedigger', 'Player Queen',
#        'Stage Manager', 'Norwegian captain', 'Guildenstern', 'Yorick',
#        'Lucianus', 'Old Fortinbras', 'Captain', " Fortinbras's Captain",
#        'Special Guest Appearance', 'Kissing Man', 'Messenger', 'Ghost',
#        'Priam', 'Lord', 'Claudius, King of Denmark', 'Player Prologue',
#        'Palace Nobleman', 'Bernardo', 'Courtier', "Fortinbras's Captain",
# ...

# %%
print(len(d))
# Out:
# 107

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %%
s = cast[ cast['character'] == 'Ophelia']   #(cast['title']=='Hamlet') &
s
# Out:
#                                    title  year                  name     type  \
# 238855        The Merry Maids of Madness  2016           Amy Bourque    actor
# 395196                    Jake Gets Paid  2009        Josie Chisholm    actor
# 453835                        Inoperable  2016       Crystal Cordero    actor
# 835461   Dogg's Hamlet, Cahoot's Macbeth  2005         Lucas Grabeel    actor
# 1315145                               11  2014   Catherine (IV) Lord    actor
# ...                                  ...   ...                   ...      ...
# 3538349         Hamlet, Son of a Kingpin  2015        Ingrid Vollset  actress
# 3551691                         D.C. Cab  1983       Marsha Warfield  actress
# 3552384                         Creature  2011  Jennifer Lynn Warren  actress
# 3562331                           Hamlet  2015       Katie (II) West  actress
# 3578802                           Hamlet  1996          Kate Winslet  actress
#
#         character     n
# ...

# %%
q =len(s)
q
# Out:
# 111

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %%
p = cast[ (cast['character'] == 'The Dude')]
p
# Out:
#                                   title  year                  name   type  \
# 261792                 The Big Lebowski  1998          Jeff Bridges  actor
# 326893               Terms & Conditions  2015           Jordan Cann  actor
# 480810                         Stranger  2000         Scott Crowell  actor
# 549887           Pizza Man vs. the Dude  2004        Chris DeMarcus  actor
# 588962                      Sweepstakes  1931           Mike Donlin  actor
# 607151                    Self Helpless  2010        Devin The Dude  actor
# 1051244  Jay and Silent Bob Strike Back  2001   Matthew (XIX) James  actor
# 1098711                   Explicit Ills  2008    Christopher Kadish  actor
# 1317786                 American Idiots  2013      Jason Loughridge  actor
# 1336484             The Winds of Autumn  1976           Steve Lyons  actor
# 1458465                         The Liq  2016        Mark Alan Meek  actor
# ...

# %%
l = len(p)
l
# Out:
# 18

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %%
s= cast[ (cast['character'] == "The Stranger")]
s
# Out:
#                             title  year                       name     type  \
# 24819                       Theeb  2014  Hassan Mutlag Al-Maraiyeh    actor
# 34302              My Time to Die  2014       Vincent H. Alexander    actor
# 64774                    Get Mean  1975               Tony Anthony    actor
# 64777    Lo straniero di silenzio  1968               Tony Anthony    actor
# 64779      Un dollaro tra i denti  1967               Tony Anthony    actor
# ...                           ...   ...                        ...      ...
# 3068419              The Stranger  1995                 Kathy Long  actress
# 3081837            Ever Since Eve  1921                Ethel Lynne  actress
# 3256243              Weitertanzen  2008             Rosa Maria Paz  actress
# 3276867               The Godsend  1980           Angela Pleasence  actress
# 3407234                Motherland  1927            Dorinea Shirley  actress
#
#             character    n
# 24819    The Stranger  3.0
# ...

# %%
w = len(s)
w
# Out:
# 208

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %%
e= cast[(cast['name'] == ' Sidney Poitier')]
e
# Out:
# Empty DataFrame
# Columns: [title, year, name, type, character, n]
# Index: []

# %%
w=len(e)
w
# Out:
# 0

# %% [markdown]
# ### How many roles has Judi Dench played?

# %%
D= cast[(cast['name'] == 'Judi Dench')]
D
# Out:
#                                                      title  year        name  \
# 2703455                              84 Charing Cross Road  1987  Judi Dench
# 2703456                                  A Handful of Dust  1988  Judi Dench
# 2703457                          A Midsummer Night's Dream  1968  Judi Dench
# 2703458                                 A Room with a View  1985  Judi Dench
# 2703459                                  A Study in Terror  1965  Judi Dench
# 2703460             Angelina Ballerina: Angelina Sets Sail  2006  Judi Dench
# 2703461                                      Casino Royale  2006  Judi Dench
# 2703462                                           Chocolat  2000  Judi Dench
# 2703463                                          Dead Cert  1974  Judi Dench
# 2703464                                    Die Another Day  2002  Judi Dench
# 2703465                                             Doogal  2006  Judi Dench
# ...

# %%
r = len(D)
r
# Out:
# 55

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
i = cast[(cast['name']== 'Cary Grant') & (cast['year']== 1940)]
i
# Out:
#                           title  year        name   type           character  \
# 840353          His Girl Friday  1940  Cary Grant  actor        Walter Burns
# 840371         My Favorite Wife  1940  Cary Grant  actor                Nick
# 840397  The Howards of Virginia  1940  Cary Grant  actor         Matt Howard
# 840399   The Philadelphia Story  1940  Cary Grant  actor  C. K. Dexter Haven
#
#           n
# 840353  1.0
# 840371  2.0
# 840397  1.0
# 840399  1.0

# %%
j = i[(i['n']==2)]
j
# Out:
#                    title  year        name   type character    n
# 840371  My Favorite Wife  1940  Cary Grant  actor      Nick  2.0

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by n.

# %%
i = cast[(cast['name']== 'Cary Grant') & (cast['year']== 1940)]
f = i.reset_index(drop=True)
f
# Out:
#                      title  year        name   type           character    n
# 0          His Girl Friday  1940  Cary Grant  actor        Walter Burns  1.0
# 1         My Favorite Wife  1940  Cary Grant  actor                Nick  2.0
# 2  The Howards of Virginia  1940  Cary Grant  actor         Matt Howard  1.0
# 3   The Philadelphia Story  1940  Cary Grant  actor  C. K. Dexter Haven  1.0

# %%
f.sort_values('n',ascending= True )     #in order by n
# Out:
#                      title  year        name   type           character    n
# 0          His Girl Friday  1940  Cary Grant  actor        Walter Burns  1.0
# 2  The Howards of Virginia  1940  Cary Grant  actor         Matt Howard  1.0
# 3   The Philadelphia Story  1940  Cary Grant  actor  C. K. Dexter Haven  1.0
# 1         My Favorite Wife  1940  Cary Grant  actor                Nick  2.0

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %%
b = cast[(cast['year']== 1950) & (cast['type']=='actor')]
b
# Out:
#                              title  year            name   type  \
# 266               Palletoori Pilla  1950  Subba Rao A.V.  actor
# 429                   Hallin Janne  1950  Kosti Aaltonen  actor
# 430                   Hallin Janne  1950  Kosti Aaltonen  actor
# 1481     Fortunes of Captain Blood  1950  Abdullah Abbas  actor
# 1497          The Baron of Arizona  1950  Abdullah Abbas  actor
# ...                            ...   ...             ...    ...
# 2439128           Restaurant Intim  1950   Steinar ?ster  actor
# 2439164            Den vita katten  1950     Alf ?stlund  actor
# 2439166       Flicka och hyacinter  1950     Alf ?stlund  actor
# 2439170         Medan staden sover  1950     Alf ?stlund  actor
# 2439172           Restaurant Intim  1950     Alf ?stlund  actor
#
#                 character     n
# 266         Kampanna Dora   4.0
# 429                 Rosvo   NaN
# 430               Vartija   NaN
# 1481          Crew Member   NaN
# ...

# %%
B = b['character']
e= (B.unique)
e
# Out:
# <bound method Series.unique of 266           Kampanna Dora
# 429                   Rosvo
# 430                 Vartija
# 1481            Crew Member
# 1497                 Indian
#                  ...
# 2439128                Cook
# 2439164    Ticket Collector
# 2439166       Viktor Ekberg
# 2439170           Andersson
# 2439172     Manager Nessing
# Name: character, Length: 16512, dtype: object>

# %% [markdown]
# ### How many roles were available for actresses in the 1950s?

# %%
c = cast[(cast['year']== 1950) & (cast['type']=='actress')]
c
# Out:
#                            title  year               name     type  \
# 2440031   A Woman of Distinction  1950  Lucienne & Ashour  actress
# 2440033          Chain Lightning  1950  Lucienne & Ashour  actress
# 2440825        A Life of Her Own  1950     Dorothy Abbott  actress
# 2440829       Annie Get Your Gun  1950     Dorothy Abbott  actress
# 2440832            Copper Canyon  1950     Dorothy Abbott  actress
# ...                          ...   ...                ...      ...
# 3610440         La vida en broma  1950      Dalia ??iguez  actress
# 3610445             Quinto patio  1950      Dalia ??iguez  actress
# 3610681  Harukanari haha no kuni  1950      Chiharu ?tomo  actress
# 3610827     Anderssonskans Kalle  1950   Ingrid ?stergren  actress
# 3611137       Akdeniz korsanlari  1950    Muazzez ?lkerer  actress
#
#                                  character    n
# 2440031                     Apache Dancers  NaN
# 2440033                     Apache Dancers  NaN
# ...

# %%
C = c['character']
f= (C.unique)
f
# Out:
# <bound method Series.unique of 2440031                       Apache Dancers
# 2440033                       Apache Dancers
# 2440825                                Model
# 2440829                       Carriage Woman
# 2440832                             Showgirl
#                          ...
# 3610440                          Rebeca Mata
# 3610445    Do?a Blanquita Z??iga de Vallarta
# 3610681                      May Takebayashi
# 3610827                  Summer Camp Manager
# 3611137                                Maria
# Name: character, Length: 5494, dtype: object>

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980?

# %%
r = cast[(cast['year']== 1950) & (cast['n']==1)]
r
# Out:
#                                              title  year                 name  \
# 1874     Abbott and Costello in the Foreign Legion  1950           Bud Abbott
# 6081                         Alitet ukhodit v gory  1950     Andrei Abrikosov
# 18365                          Dos gallos de pelea  1950         Luis Aguilar
# 24532                                  Akher kedba  1950     Farid Al Atrache
# 26963                            Vom Teufel gejagt  1950          Hans Albers
# ...                                            ...   ...                  ...
# 3589600                               Stage Fright  1950           Jane Wyman
# 3589609                        The Glass Menagerie  1950           Jane Wyman
# 3603481                          U nikh est Rodina  1950  Natalya Zashchipina
# 3606765            Die lustigen Weiber von Windsor  1950        Sonja Ziemann
# 3608813                                  Valentina  1950         Olga Zubarry
#
# ...

# %%
k=r['character']
len(k)
# Out:
# 900

# %% [markdown]
# ### How many non-leading roles were available through from the beginning of film history through 1980?

# %%
s = cast[(cast['year']== 1980)]
s
# Out:
#                                                     title  year  \
# 195                         Cheech and Chong's Next Movie  1980
# 423                                          Aurinkotuuli  1980
# 472      Bob Hope's All-Star Look at TV's Prime Time Wars  1980
# 597                                           Raging Bull  1980
# 998                                                Afanti  1980
# ...                                                   ...   ...
# 3610679                                  Tsigoineruwaizen  1980
# 3610867                                             Akrep  1980
# 3610915                                      Gerzek Saban  1980
# 3610960                                Kizi da anasi gibi  1980
# 3610972                                       Banker Bilo  1980
#
#                    name     type          character     n
# 195            Bobby A.    actor            Doorman  33.0
# 423      Jouko Aaltonen    actor     Man on lecture  12.0
# ...

# %%
s.isna().sum()
# Out:
# title           0
# year            0
# name            0
# type            0
# character       0
# n            4227
# dtype: int64

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
s = cast[(cast['year']== 1980) & (cast['n'] < 10)]
s
# Out:
#                                      title  year               name     type  \
# 1208                 Fantozzi contro tutti  1980  Diego Abatantuono    actor
# 1221                         Il pap'occhio  1980  Diego Abatantuono    actor
# 1245                   Prestami tua moglie  1980  Diego Abatantuono    actor
# 1374               Athkiya' laken aghbiya'  1980       Rushdy Abaza    actor
# 2128                             Hangar 18  1980      Philip Abbott    actor
# ...                                    ...   ...                ...      ...
# 3610590  Kairaku gakuen: kinjirareta asobi  1980          Ayako ?ta  actress
# 3610678                   Tsigoineruwaizen  1980        Naoko ?tani  actress
# 3610679                   Tsigoineruwaizen  1980        Naoko ?tani  actress
# 3610867                              Akrep  1980        Ayfer ?zcan  actress
# 3610915                       Gerzek Saban  1980          ?lk? ?zen  actress
#
#                             character    n
# ...
